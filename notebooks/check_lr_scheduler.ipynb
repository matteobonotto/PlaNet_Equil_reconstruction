# %%
import numpy as np

# %%
initial_learning_rate = 0.001
decay_rate = 0.75
decay_steps = 70000

def decayed_learning_rate(step):
    return initial_learning_rate * decay_rate ** (step / decay_steps)

for i in range(400):
    print(i, decayed_learning_rate(i*70000/64))
# Out:
# 0 0.001
# 1 0.0009955150551557359
# 2 0.0009910502250417275
# 3 0.00098660541944452
# 4 0.000982180548555259
# 5 0.0009777755229678795
# 6 0.0009733902536772969
# 7 0.0009690246520776098
# 8 0.0009646786299603095
# 9 0.000960352099512497
# 10 0.0009560449733151102
# 11 0.0009517571643411558
# 12 0.0009474885859539524
# 13 0.000943239151905379
# 14 0.0009390087763341328
# 15 0.0009347973737639942
# 16 0.0009306048591020996
# 17 0.0009264311476372223
# 18 0.000922276155038061
# 19 0.0009181397973515353
# 20 0.0009140219910010898
# 21 0.0009099226527850052
# 22 0.0009058416998747179
# 23 0.0009017790498131452
# 24 0.0008977346205130203
# 25 0.0008937083302552329
# 26 0.0008897000976871787
# 27 0.0008857098418211151
# 28 0.0008817374820325255
# 29 0.0008777829380584892
# 30 0.0008738461299960606
# 31 0.0008699269783006546
# 32 0.0008660254037844386
# 33 0.0008621413276147338
# 34 0.000858274671312421
# 35 0.0008544253567503557
# 36 0.0008505933061517896
# 37 0.0008467784420887985
# ...
